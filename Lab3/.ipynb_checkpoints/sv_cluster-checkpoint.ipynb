# %% [markdown]
# # 1. Постановка задачи
# В рамках данные лабораторной работы необходимо реализовать метод sv-кластеризации и проверить его работу на хорошо и плохо отделимых модельных данных.
#
# ## План работы:
# 1. Подготовка модельных данных
# 2. Реализация SVC-алгоритма
# 3. Кластеризация с разными значениями гиперпараметров. Оценка качества и выбор оптимальных значений гиперпараметров.
# 4. Графическая иллюстрация результатов, таблицы.

# %% [markdown]
# # 2. Алгоритм SVC-кластеризации
# Алгоритм SVC-кластеризации включает в себя следующие шаги:
# 1. Построение ядерной матрицы: $K = \{k_{ij}\}, i, j = 1, ..., n$
# $$k_{ij} = k(x_i, x_j) = exp(-q ||x_i - x_j||^2)$$
# 2. Решение задачи квадратичного программирования. Необходимо найти множители Лагранжа $\mu_i, i = 1, \dots, n$. Любые множители меньше $10^{−3}$ будем считать нулем. $$ \max\limits_{\mu_i} W $$ $$ W = \sum\limits_{i=1}^n \mu_i k(x_i, x_i) - \sum\limits_{i=1}^n \sum\limits_{j=1}^n k(x_i, x_j)$$ $$\sum\limits_{i=1}^n \mu_i = 1$$ $$0 \leq \mu_i \leq C, i = 1, \dots, n$$
# 3. Классификация векторов:
# * Связанные опорные вектора (BSVs): $\mu_i = C$ лежат вне гиперсферы
# * Опорные вектора (SVs): $0 < \mu_i < C$ лежат на поверхности гиперсферы.
# * Другие векторы (OVs): $\mu_i = 0$ - внутри гиперсферы или на поверхности
# 4. Расстояние от центра гиперсферы до вектора x и радиусы гиперсфер: $$r^2(x) = k(x,x) - 2\sum\limits_{i=1}^n \mu_i k(x_i, x) + \sum\limits_{i=1}^n \sum\limits_{j=1}^n \mu_i \mu_j k(x_i, x_j)$$ $$R = r(x_i), x_i \in SVs$$
# 5. Маркировка кластеров. Необходимо построить матрицу смежности A. $$
# A_{ij} =  \begin{cases}
#    1 &\text{, если $r(y) \leq R, \forall y \in [x_i, x_j]$}\\
#    0 &\text{, иначе}
#  \end{cases}
# $$
# 6. Находим кластеры как связанные компоненты графа, индуцированного матрицей A. Связанные опорные векторы не кластеризуются и впоследствии относятся к кластерам с ближайшим к ним центром.

# %% [markdown]
# # 3. Критерии оценки качества кластеризации

# %%
from pandas import DataFrame
from matplotlib import pyplot
import numpy as np
import cvxopt

class SVC:
    zero_mu = 1e-3

    @staticmethod
    def init_clustering(sample, p, q):
        svc = SVC(sample, p, q)
        svc.__find_kernel_matrix()
        svc.__find_mu()
        svc.__find_segment_matrix()
        svc.__find_clusters()
        return svc

    def show_plot(self):
        labels = np.zeros(self.sample.shape[0])
        for i in self.clusters.keys():
            for j in self.clusters[i]:
                labels[j] = int(i)
        if len(self.clusters) >= 10:
            print("Number of clusters is more or equals 10")
            return
        df = DataFrame(dict(x=self.sample[:, 0], y=self.sample[:, 1], label=labels))
        colors = {1: 'r', 2: 'b', 3: 'g', 4: 'c', 5: 'm', 6: 'y', 7: 'k', 8: 'b', 9: 'c'}
        fig, ax = pyplot.subplots()
        grouped = df.groupby('label')
        for key, group in grouped:
            group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])

        # Помечаем звездочками опорные вектора
        svs_val_x = [self.sample[i][0] for i in self.svs]
        svs_val_y = [self.sample[i][1] for i in self.svs]
        ax.scatter(x=svs_val_x, y=svs_val_y, marker='*', color='black')

        # Помечаем крестами связанные опорные вектора
        svs_val_x = [self.sample[i][0] for i in self.bsvs]
        svs_val_y = [self.sample[i][1] for i in self.bsvs]
        ax.scatter(x=svs_val_x, y=svs_val_y, marker='X', color='black')

        pyplot.show()

    # Don't use constructor, use init_clustering
    # sample - выборка, которую кластеризуем
    def __init__(self, sample, p, q):
        self.sample = sample
        self.N = len(sample)
        self.p = p
        self.q = q
        self.C = 1 / (self.N * p)

        # Ядерная матрица
        self.km = None
        # Вектор множителей Лагранжа \mu
        self.mu = None
        # Матрица смежности A
        self.segment_matrix = None
        self.clusters = None
        self.svs = None
        self.bsvs = None

    # Инициализация ядерной матрицы
    def __find_kernel_matrix(self):
        self.km = np.zeros((self.N, self.N))
        for i in range(self.N):
            for j in range(self.N):
                self.km[i, j] = self.__kernel(self.sample[i], self.sample[j])

    # Инициализируем множители Лагранжа \mu_i
    def __find_mu(self):
        P = cvxopt.matrix(self.km)
        q = cvxopt.matrix(self.km.diagonal().reshape(self.N, 1))
        G1 = cvxopt.spmatrix(-1, range(self.N), range(self.N))
        G2 = cvxopt.spmatrix(1, range(self.N), range(self.N))
        G = cvxopt.sparse([G1, G2])
        h1 = np.zeros(self.N)
        h2 = np.full(self.N, self.C)
        h = cvxopt.matrix(np.concatenate((h1, h2), axis=0), (2 * self.N, 1))
        A = cvxopt.matrix(1.0, (1, self.N))
        b = cvxopt.matrix(1.0)
        sol = cvxopt.solvers.qp(P, q, G, h, A, b)
        # print(sol['x'])
        # res = np.array(sol['x'])
        # print(np.any(res[res > SVC.zero_mu]))
        self.mu = np.array(sol['x'])

    def __find_segment_matrix(self):
        svs_tmp = np.array(self.C > self.mu) * np.array(self.mu > SVC.zero_mu)
        self.svs = np.where(svs_tmp == True)[0]
        bsvs_tmp = np.array(self.mu == self.C)
        self.bsvs = np.where(bsvs_tmp==True)[0]
        r = np.mean([self.__r2_func(self.sample[i]) for i in self.svs[:5]])
        self.segment_matrix = np.zeros((self.N, self.N))
        for i in range(self.N):
            if i not in self.bsvs:
                for j in range(i, self.N):
                    if j not in self.bsvs:
                        self.segment_matrix[i, j] = self.segment_matrix[j, i] = self.__segment(self.sample[i], self.sample[j], r)

    def __find_clusters(self):
        ids = list(range(self.N))
        self.clusters = {}
        num_clusters = 0
        while ids:
            num_clusters += 1
            self.clusters[num_clusters] = []
            curr_id = ids.pop(0)
            queue = [curr_id]
            while queue:
                cid = queue.pop(0)
                for i in ids:
                    if self.segment_matrix[i, cid]:
                        queue.append(i)
                        ids.remove(i)
                self.clusters[num_clusters].append(cid)

    def __r2_func(self, x):
        return 1 - 2 * np.sum(
            self.mu[i] * self.__kernel(self.sample[i], x) for i in range(self.N)
        )

    def __kernel(self, x1, x2):
        return np.exp(-self.q * np.sum((x1 - x2) ** 2, axis=-1))

    # Вычисление элемента матрицы смежности A_ij
    def __segment(self, x1, x2, r, n=10):
        for i in range(n):
            x = x1 + (x2 - x1) * i / (n + 1)
            if self.__r2_func(x) > r:
                return False
        return True

# %%
from scipy.stats import multivariate_normal

def get_sample(n, s):
    m1 = np.array([2, 1])
    m2 = np.array([0, 10])
    m3 = np.array([20, 8])
    size = int(n / 3)
    cluster1 = multivariate_normal(mean=m1, cov=s).rvs(size)
    cluster2 = multivariate_normal(mean=m2, cov=s).rvs(size)
    if n % 3 != 0:
        size += 1
    cluster3 = multivariate_normal(mean=m3, cov=s).rvs(size)

    return np.vstack([cluster1, cluster2, cluster3])

n = 100
s_good = np.array([[0.5, 0.4],
                   [0.4, 0.8]])
s_bad = (s_good + 2) * 5

# %% [markdown]
# Хорошо отделимые данные:

# %%
good_sample = get_sample(100, s_good)
pyplot.scatter(x=good_sample[:, 0], y=good_sample[:, 1])

# %% [markdown]
# Плохо отделимые данные:

# %%
bad_sample = get_sample(100, s_bad)
pyplot.scatter(x=bad_sample[:, 0], y=bad_sample[:, 1])

# %%
def research(sample):
    max = np.max([np.sum((sample[i] - sample[j]) ** 2, axis=-1) for i in range(len(sample)) for j in range(len(sample))])
    q1 = 1 / max
    print(f"q1 = {q1}")

    pq_set = (
        (0.01, q1),
        (0.01, 0.1),
        (0.01, 0.5),
        (0.1, 0.1),
        (0.5, 0.1),
        (0.9, 0.1),
        (1, 0.1)
    )

    for pq in pq_set:
        svc = SVC.init_clustering(sample, p=pq[0], q=pq[1])
        print("p, q, clusters count, SVs, BSVs")
        print(pq[0], pq[1], len(svc.clusters), len(svc.svs), len(svc.bsvs))
        svc.show_plot()

# %%
research(good_sample)
# Out:
# q1 = 0.0017621120864001088
#      pcost       dcost       gap    pres   dres
#  0:  1.3513e+00 -1.0168e+02  4e+02  1e+00  3e-16
#  1:  1.3622e+00 -2.6981e+01  3e+01  7e-03  5e-16
#  2:  1.3636e+00  8.5875e-01  5e-01  7e-05  8e-16
#  3:  1.3609e+00  1.2594e+00  1e-01  1e-05  4e-16
#  4:  1.3520e+00  1.2575e+00  9e-02  1e-05  3e-16
#  5:  1.3438e+00  1.3096e+00  3e-02  2e-06  3e-16
#  6:  1.3367e+00  1.3246e+00  1e-02  2e-07  3e-16
#  7:  1.3334e+00  1.3301e+00  3e-03  5e-16  4e-16
#  8:  1.3320e+00  1.3320e+00  5e-05  2e-16  3e-16
#  9:  1.3320e+00  1.3320e+00  5e-07  3e-16  3e-16
# Optimal solution found.
# /var/folders/3m/183xym5n6_g55n2641z7dghw0000gq/T/ipykernel_13779/1894127474.py:120: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return 1 - 2 * np.sum(
# p, q, clusters count, SVs, BSVs
# 0.01 0.0017621120864001088 1 3 0
#      pcost       dcost       gap    pres   dres
#  0:  1.1040e+00 -1.0093e+02  4e+02  1e+00  3e-16
#  1:  1.1175e+00 -2.6596e+01  3e+01  5e-03  5e-16
#  2:  1.1189e+00  7.0968e-01  4e-01  5e-05  5e-16
#  3:  1.1087e+00  9.8649e-01  1e-01  1e-05  3e-16
#  4:  1.0950e+00  1.0701e+00  2e-02  2e-16  3e-16
#  5:  1.0910e+00  1.0851e+00  6e-03  2e-16  3e-16
#  6:  1.0901e+00  1.0863e+00  4e-03  3e-16  3e-16
#  7:  1.0893e+00  1.0885e+00  8e-04  7e-16  3e-16
#  8:  1.0890e+00  1.0889e+00  5e-05  2e-16  2e-16
#  9:  1.0890e+00  1.0890e+00  1e-06  3e-16  3e-16
# 10:  1.0890e+00  1.0890e+00  1e-08  2e-16  2e-16
# Optimal solution found.
# /var/folders/3m/183xym5n6_g55n2641z7dghw0000gq/T/ipykernel_13779/1894127474.py:120: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return 1 - 2 * np.sum(
# p, q, clusters count, SVs, BSVs
# 0.01 0.1 3 13 0
#      pcost       dcost       gap    pres   dres
#  0:  1.0520e+00 -1.0089e+02  1e+02  3e-17  2e-16
#  1:  1.0518e+00 -1.8480e+00  3e+00  5e-16  4e-16
#  2:  1.0555e+00  9.1774e-01  1e-01  1e-16  2e-16
#  3:  1.0502e+00  1.0248e+00  3e-02  2e-16  2e-16
#  4:  1.0465e+00  1.0392e+00  7e-03  2e-16  2e-16
#  5:  1.0449e+00  1.0431e+00  2e-03  4e-16  3e-16
#  6:  1.0445e+00  1.0441e+00  4e-04  4e-16  2e-16
#  7:  1.0444e+00  1.0443e+00  1e-05  5e-16  2e-16
#  8:  1.0444e+00  1.0444e+00  4e-07  6e-16  2e-16
# Optimal solution found.
# /var/folders/3m/183xym5n6_g55n2641z7dghw0000gq/T/ipykernel_13779/1894127474.py:120: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return 1 - 2 * np.sum(
# p, q, clusters count, SVs, BSVs
# 0.01 0.5 3 25 0
#      pcost       dcost       gap    pres   dres
#  0:  1.1040e+00 -9.0662e+00  2e+02  1e+01  3e-16
#  1:  1.1200e+00 -7.6057e+00  9e+00  4e-02  4e-16
#  2:  1.1197e+00  7.3549e-01  4e-01  1e-03  3e-16
#  3:  1.1030e+00  9.7303e-01  1e-01  2e-16  3e-16
#  4:  1.0969e+00  1.0657e+00  3e-02  2e-16  2e-16
#  5:  1.0916e+00  1.0858e+00  6e-03  2e-16  3e-16
#  6:  1.0899e+00  1.0885e+00  1e-03  2e-16  3e-16
#  7:  1.0895e+00  1.0892e+00  3e-04  2e-16  3e-16
#  8:  1.0894e+00  1.0894e+00  5e-06  3e-16  3e-16
#  9:  1.0894e+00  1.0894e+00  7e-08  6e-16  2e-16
# Optimal solution found.
# /var/folders/3m/183xym5n6_g55n2641z7dghw0000gq/T/ipykernel_13779/1894127474.py:120: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return 1 - 2 * np.sum(
# p, q, clusters count, SVs, BSVs
# 0.1 0.1 3 15 0
#      pcost       dcost       gap    pres   dres
#  0:  1.1040e+00 -9.4385e-01  2e+02  1e+01  3e-16
#  1:  1.1218e+00 -8.9914e-01  3e+00  9e-02  4e-16
#  2:  1.1231e+00  8.0728e-01  3e-01  2e-16  3e-16
#  3:  1.1195e+00  1.0869e+00  3e-02  5e-16  3e-16
#  4:  1.1123e+00  1.1055e+00  7e-03  5e-16  3e-16
#  5:  1.1095e+00  1.1079e+00  2e-03  5e-17  3e-16
#  6:  1.1089e+00  1.1084e+00  5e-04  4e-17  2e-16
#  7:  1.1087e+00  1.1086e+00  1e-04  3e-16  2e-16
#  8:  1.1087e+00  1.1087e+00  4e-06  4e-16  2e-16
#  9:  1.1087e+00  1.1087e+00  5e-08  9e-17  3e-16
# Optimal solution found.
# /var/folders/3m/183xym5n6_g55n2641z7dghw0000gq/T/ipykernel_13779/1894127474.py:120: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return 1 - 2 * np.sum(
# p, q, clusters count, SVs, BSVs
# 0.5 0.1 11 54 0
# Number of clusters is more or equals 10
#      pcost       dcost       gap    pres   dres
#  0:  1.1040e+00 -2.6991e-02  2e+02  1e+01  3e-16
#  1:  1.1218e+00 -2.0495e-03  4e+00  2e-01  4e-16
#  2:  1.1262e+00  6.6002e-01  5e-01  2e-16  4e-16
#  3:  1.1260e+00  1.1073e+00  2e-02  2e-16  4e-16
#  4:  1.1246e+00  1.1209e+00  4e-03  4e-16  3e-16
#  5:  1.1240e+00  1.1231e+00  9e-04  8e-16  3e-16
#  6:  1.1237e+00  1.1235e+00  2e-04  3e-16  3e-16
#  7:  1.1236e+00  1.1236e+00  4e-05  4e-16  2e-16
#  8:  1.1236e+00  1.1236e+00  8e-06  4e-16  2e-16
#  9:  1.1236e+00  1.1236e+00  1e-07  3e-17  3e-16
# Optimal solution found.
# p, q, clusters count, SVs, BSVs
# 0.9 0.1 19 91 0
# Number of clusters is more or equals 10
#      pcost       dcost       gap    pres   dres
#  0:  1.1040e+00  8.8727e-02  2e+02  1e+01  3e-16
#  1:  1.1219e+00  1.1340e-01  4e+00  2e-01  4e-16
#  2:  1.1264e+00  7.1671e-01  5e-01  8e-03  5e-16
#  3:  1.1270e+00  1.1187e+00  9e-03  1e-04  8e-16
#  4:  1.1270e+00  1.1269e+00  9e-05  1e-06  4e-16
#  5:  1.1270e+00  1.1270e+00  9e-07  1e-08  4e-16
# Optimal solution found.
# p, q, clusters count, SVs, BSVs
# 1 0.1 22 67 0
# Number of clusters is more or equals 10

# %%
research(bad_sample)
# Out:
# q1 = 0.000779220463808095
#      pcost       dcost       gap    pres   dres
#  0:  1.3667e+00 -1.0214e+02  4e+02  1e+00  3e-16
#  1:  1.4068e+00 -2.7284e+01  3e+01  9e-03  6e-16
#  2:  1.4120e+00  8.2949e-01  6e-01  9e-05  6e-16
#  3:  1.4029e+00  1.1892e+00  2e-01  3e-05  4e-16
#  4:  1.3770e+00  1.2121e+00  2e-01  1e-05  3e-16
#  5:  1.3569e+00  1.3145e+00  4e-02  2e-06  4e-16
#  6:  1.3492e+00  1.3234e+00  3e-02  9e-07  3e-16
#  7:  1.3406e+00  1.3384e+00  2e-03  6e-08  4e-16
#  8:  1.3397e+00  1.3397e+00  2e-05  6e-10  3e-16
#  9:  1.3397e+00  1.3397e+00  2e-07  6e-12  3e-16
# Optimal solution found.
# /var/folders/3m/183xym5n6_g55n2641z7dghw0000gq/T/ipykernel_13779/1894127474.py:120: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return 1 - 2 * np.sum(
# p, q, clusters count, SVs, BSVs
# 0.01 0.000779220463808095 1 3 0
#      pcost       dcost       gap    pres   dres
#  0:  1.0332e+00 -1.0070e+02  1e+02  6e-16  3e-16
#  1:  1.0330e+00 -1.4308e+00  2e+00  2e-16  6e-16
#  2:  1.0330e+00  9.5191e-01  8e-02  3e-16  3e-16
#  3:  1.0308e+00  1.0180e+00  1e-02  2e-16  3e-16
#  4:  1.0296e+00  1.0267e+00  3e-03  7e-16  3e-16
#  5:  1.0291e+00  1.0283e+00  8e-04  3e-16  3e-16
#  6:  1.0290e+00  1.0288e+00  2e-04  6e-16  3e-16
#  7:  1.0289e+00  1.0289e+00  1e-05  2e-16  3e-16
#  8:  1.0289e+00  1.0289e+00  2e-07  6e-16  3e-16
# Optimal solution found.
# /var/folders/3m/183xym5n6_g55n2641z7dghw0000gq/T/ipykernel_13779/1894127474.py:120: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return 1 - 2 * np.sum(
# p, q, clusters count, SVs, BSVs
# 0.01 0.1 7 37 0
#      pcost       dcost       gap    pres   dres
#  0:  1.0137e+00 -1.0065e+02  1e+02  3e-17  2e-16
#  1:  1.0136e+00 -5.2448e-01  2e+00  2e-16  4e-16
#  2:  1.0127e+00  9.9087e-01  2e-02  1e-16  2e-16
#  3:  1.0123e+00  1.0097e+00  3e-03  2e-16  2e-16
#  4:  1.0122e+00  1.0118e+00  4e-04  2e-16  3e-16
#  5:  1.0121e+00  1.0121e+00  4e-05  2e-16  3e-16
#  6:  1.0121e+00  1.0121e+00  3e-06  2e-16  2e-16
#  7:  1.0121e+00  1.0121e+00  7e-08  3e-16  2e-16
# Optimal solution found.
# /var/folders/3m/183xym5n6_g55n2641z7dghw0000gq/T/ipykernel_13779/1894127474.py:120: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return 1 - 2 * np.sum(
# p, q, clusters count, SVs, BSVs
# 0.01 0.5 26 67 0
# Number of clusters is more or equals 10
#      pcost       dcost       gap    pres   dres
#  0:  1.0332e+00 -9.1163e+00  1e+01  1e-15  4e-16
#  1:  1.0329e+00  7.3587e-01  3e-01  2e-16  4e-16
#  2:  1.0306e+00  1.0149e+00  2e-02  2e-16  3e-16
#  3:  1.0295e+00  1.0266e+00  3e-03  5e-16  3e-16
#  4:  1.0291e+00  1.0284e+00  7e-04  3e-16  3e-16
#  5:  1.0289e+00  1.0288e+00  1e-04  3e-16  3e-16
#  6:  1.0289e+00  1.0289e+00  6e-06  2e-16  3e-16
#  7:  1.0289e+00  1.0289e+00  9e-08  5e-16  3e-16
# Optimal solution found.
# p, q, clusters count, SVs, BSVs
# 0.1 0.1 7 37 0
#      pcost       dcost       gap    pres   dres
#  0:  1.0332e+00 -9.9734e-01  2e+02  1e+01  3e-16
#  1:  1.0391e+00 -9.5336e-01  3e+00  7e-02  4e-16
#  2:  1.0408e+00  7.7963e-01  3e-01  2e-16  3e-16
#  3:  1.0379e+00  1.0144e+00  2e-02  2e-16  3e-16
#  4:  1.0345e+00  1.0289e+00  6e-03  1e-16  3e-16
#  5:  1.0332e+00  1.0316e+00  2e-03  9e-17  3e-16
#  6:  1.0327e+00  1.0322e+00  5e-04  2e-16  3e-16
#  7:  1.0325e+00  1.0325e+00  6e-05  2e-16  3e-16
#  8:  1.0325e+00  1.0325e+00  1e-05  4e-16  3e-16
#  9:  1.0325e+00  1.0325e+00  3e-07  4e-16  3e-16
# Optimal solution found.
# /var/folders/3m/183xym5n6_g55n2641z7dghw0000gq/T/ipykernel_13779/1894127474.py:120: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   return 1 - 2 * np.sum(
# p, q, clusters count, SVs, BSVs
# 0.5 0.1 12 59 0
# Number of clusters is more or equals 10
#      pcost       dcost       gap    pres   dres
#  0:  1.0332e+00 -9.2800e-02  2e+02  1e+01  3e-16
#  1:  1.0391e+00 -6.8632e-02  4e+00  2e-01  4e-16
#  2:  1.0450e+00  6.0229e-01  4e-01  3e-16  4e-16
#  3:  1.0448e+00  1.0216e+00  2e-02  1e-16  4e-16
#  4:  1.0432e+00  1.0382e+00  5e-03  7e-17  3e-16
#  5:  1.0425e+00  1.0417e+00  8e-04  2e-16  3e-16
#  6:  1.0422e+00  1.0420e+00  2e-04  3e-16  4e-16
#  7:  1.0421e+00  1.0421e+00  1e-05  6e-16  3e-16
#  8:  1.0421e+00  1.0421e+00  5e-07  4e-16  3e-16
# Optimal solution found.
# p, q, clusters count, SVs, BSVs
# 0.9 0.1 16 91 0
# Number of clusters is more or equals 10
#      pcost       dcost       gap    pres   dres
#  0:  1.0332e+00  2.1379e-02  2e+02  1e+01  4e-16
#  1:  1.0392e+00  4.5269e-02  4e+00  2e-01  4e-16
#  2:  1.0454e+00  6.5696e-01  5e-01  8e-03  5e-16
#  3:  1.0465e+00  1.0357e+00  1e-02  2e-04  7e-16
#  4:  1.0465e+00  1.0464e+00  1e-04  2e-06  4e-16
#  5:  1.0465e+00  1.0465e+00  1e-06  2e-08  4e-16
#  6:  1.0465e+00  1.0465e+00  1e-08  2e-10  4e-16
# Optimal solution found.
# p, q, clusters count, SVs, BSVs
# 1 0.1 71 61 0
# Number of clusters is more or equals 10
